# %%
# !pip install groq pandas

# %%
import csv
from groq import Groq

# Initialize the Groq client
client = Groq(
    api_key="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"  # Replace with your actual API key
)

# Function to call Groq API with LLAMA 3 model
def call_groq_api(prompt, model="llama3-70b-8192"):
    try:
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            model=model,
        )
        return chat_completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling Groq API: {e}")
        return None

# Function to read notes from a text file
def read_notes(input_file):
    with open(input_file, 'r') as file:
        return file.read()

# Function to craft the prompt for generating quiz from notes
def generate_quiz_from_notes(notes):
    prompt = f"""Generate a quiz from the following notes. The quiz should contain exactly 30 questions, 
    with each question having 3 options (A, B, C, D) and specify the correct answer. Format each question as follows:

    **Question X**
    [Question text] (Category) (Topic)
    A) [Option A]
    B) [Option B]
    C) [Option C]
    D) [Option D]
    Correct Answer: [Correct option]

    Where X is the question number. Ensure there's a blank line between each question.
    Also mark the question with its category like [Question text] (Category)
    Categories:
    - Theoretical : 3 Questions
    - Understanding : 3 Questions
    - Pseudocode : 3 Questions
    - Remembering : 3 Questions
    - Logical Reasoning : 3 Questions
    Each category should have minimum 3 questions
    Also Tag the questions with their topic like [Question text] (Category) (Topic), topics will be based on the notes

    IMPORTANT: 
    - The quiz should have the equal number of questions for each category and topics present in the notes.
    - Dont use this () syntax in the notes, it will break the script.

    Notes:\n{notes}"""
    
    return call_groq_api(prompt)

# Function to process the API response and save the quiz to a CSV
def save_quiz_to_csv(quiz_text, output_file):
    print("Raw Quiz Text from API:\n", quiz_text)
    questions = []
    current_question = {}
    
    lines = quiz_text.split("\n")
    for line in lines:
        line = line.strip()
        if line.startswith("**Question"):
            if current_question:
                questions.append(current_question)
            current_question = {"Question": "", "Option A": "", "Option B": "", "Option C": "","Option D": "", "Correct Answer": ""}
        elif line.startswith("What") or line.startswith("Which") or line.endswith("?"):
            current_question["Question"] = line
        elif line.startswith("A)"):
            current_question["Option A"] = line[3:].strip()
        elif line.startswith("B)"):
            current_question["Option B"] = line[3:].strip()
        elif line.startswith("C)"):
            current_question["Option C"] = line[3:].strip()
        elif line.startswith("D)"):
            current_question["Option D"] = line[3:].strip()
        elif line.startswith("Correct Answer:"):
            current_question["Correct Answer"] = line[16:].strip()
    
    if current_question:
        questions.append(current_question)
    
    # Write the questions to a CSV file
    with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ["Question", "Option A", "Option B", "Option C","Option D", "Correct Answer"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for question in questions:
            writer.writerow(question)
    
    print(f"Quiz saved to {output_file} with {len(questions)} questions.")

# Main function to tie everything together
def create_quiz(input_file, output_file):
    notes = read_notes(input_file)
    quiz_text = generate_quiz_from_notes(notes)
    
    if quiz_text:
        save_quiz_to_csv(quiz_text, output_file)
    else:
        print("Failed to generate quiz.")

# Example usage
input_file = "Module1_Notes_to_Quiz/Notes.txt"  # Your text file with notes
output_file = "Module1_Notes_to_Quiz/quiz.csv"  # The output CSV file
create_quiz(input_file, output_file)
# Out:
# Raw Quiz Text from API:
#  Here is the quiz based on the provided notes:
#
# **Question 1**
# What is the primary use of algorithms and data structures in computer science? (Theoretical) (Understanding Data Structures and Algorithms)
# A) To build complex software systems
# B) To understand the intricacies of computer hardware
# C) To build efficient, optimized solutions to complex problems
# D) To develop artificial intelligence
# Correct Answer: C) To build efficient, optimized solutions to complex problems
#
# **Question 2**
# What is the time complexity of searching for an element in an unsorted array? (Understanding) (Time Complexity of Searching in an Unsorted Array)
# A) O(log n)
# B) O(n)
# C) O(n log n)
# D) O(1)
# Correct Answer: B) O(n)
#
# **Question 3**
# What is the advantage of arrays in terms of memory usage? (Remembering) (Characteristics of Arrays)
# A) Arrays use more memory than other data structures
# B) Arrays use contiguous memory, making them memory-efficient
# C) Arrays are not suitable for large datasets
# D) Arrays are only used for dynamic data
# Correct Answer: B) Arrays use contiguous memory, making them memory-efficient
#
# **Question 4**
# What is the disadvantage of arrays in terms of size? (Logical Reasoning) (Disadvantages of Arrays)
# A) Arrays can be too large
# B) Arrays have a fixed size
# C) Arrays are not suitable for small datasets
# D) Arrays are only used for dynamic data
# Correct Answer: B) Arrays have a fixed size
#
# **Question 5**
# What is the primary difference between singly linked lists and doubly linked lists? (Pseudocode) (Doubly Linked Lists vs. Singly Linked Lists)
# A) The number of nodes in the list
# B) The direction of traversal
# C) The memory usage
# D) The data type stored in the nodes
# Correct Answer: B) The direction of traversal
#
# **Question 6**
# What is the advantage of doubly linked lists in terms of deletion? (Understanding) (Advantages of Doubly Linked Lists)
# A) It takes longer to delete a node
# B) It is more complex to delete a node
# C) It is faster to delete a node
# D) It is not possible to delete a node
# Correct Answer: C) It is faster to delete a node
#
# **Question 7**
# What is the time complexity of summing elements in an array using the provided pseudocode? (Pseudocode) (Pseudocode for Summing Elements in an Array)
# A) O(log n)
# B) O(n)
# C) O(n log n)
# D) O(1)
# Correct Answer: B) O(n)
#
# **Question 8**
# What is the space complexity of summing elements in an array using the provided pseudocode? (Remembering) (Analysis)
# A) O(n)
# B) O(1)
# C) O(log n)
# D) O(n log n)
# Correct Answer: B) O(1)
#
# **Question 9**
# What is the primary property of a Binary Search Tree (BST)? (Theoretical) (Binary Search Trees)
# A) Each node has at most three children
# B) The value of the left child is greater than its parent node
# C) The value of the left child is less than its parent node
# D) The tree is always balanced
# Correct Answer: C) The value of the left child is less than its parent node
#
# **Question 10**
# What is the time complexity of search operations in a balanced Binary Search Tree? (Understanding) (Time Complexity of Binary Search Trees)
# A) O(n)
# B) O(log n)
# C) O(n log n)
# D) O(1)
# Correct Answer: B) O(log n)
#
# **Question 11**
# What is the primary application of Max-Heaps? (Logical Reasoning) (Max-Heap Characteristics)
# A) Database indexing
# B) Priority queues
# C) File system navigation
# D) Browser history navigation
# Correct Answer: B) Priority queues
#
# **Question 12**
# What is the time complexity of insertion and deletion operations in a Max-Heap? (Pseudocode) (Operations and Time Complexities)
# A) O(n)
# B) O(log n)
# C) O(n log n)
# D) O(1)
# Correct Answer: B) O(log n)
#
# **Question 13**
# What is the primary advantage of balanced trees like AVL and Red-Black trees? (Remembering) (Balanced Trees: AVL and Red-Black Trees)
# A) They are more complex to implement
# B) They are less efficient in terms of time complexity
# C) They ensure the height of the tree remains small
# D) They are only used for small datasets
# Correct Answer: C) They ensure the height of the tree remains small
#
# **Question 14**
# What is the difference between AVL trees and Red-Black trees? (Theoretical) (Balanced Trees: AVL and Red-Black Trees)
# A) AVL trees are balanced, while Red-Black trees are not
# B) AVL trees use rotations, while Red-Black trees use coloring
# C) AVL trees are used for small datasets, while Red-Black trees are used for large datasets
# D) AVL trees are less efficient than Red-Black trees
# Correct Answer: B) AVL trees use rotations, while Red-Black trees use coloring
#
# **Question 15**
# What is the primary use of arrays in real-world applications? (Logical Reasoning) (Applications of Arrays)
# A) Game development
# B) Computer graphics
# C) Maintaining a list of predefined settings or configuration values
# D) All of the above
# Correct Answer: D) All of the above
#
# **Question 16**
# What is the advantage of singly linked lists in terms of memory usage? (Remembering) (Doubly Linked Lists vs. Singly Linked Lists)
# A) They use less memory than doubly linked lists
# B) They use more memory than doubly linked lists
# C) They are only used for large datasets
# D) They are not suitable for dynamic data
# Correct Answer: A) They use less memory than doubly linked lists
#
# **Question 17**
# What is the disadvantage of doubly linked lists in terms of complexity? (Logical Reasoning) (Disadvantages of Doubly Linked Lists)
# A) They are less complex than singly linked lists
# B) They are more complex than singly linked lists
# C) They are only used for small datasets
# D) They are not suitable for dynamic data
# Correct Answer: B) They are more complex than singly linked lists
#
# **Question 18**
# What is the primary application of Binary Search Trees? (Understanding) (Applications of Binary Search Trees)
# A) Database indexing
# B) File system navigation
# C) Browser history navigation
# D) All of the above
# Correct Answer: A) Database indexing
#
# **Question 19**
# What is the time complexity of searching for an element in a Binary Search Tree? (Pseudocode) (Time Complexity of Binary Search Trees)
# A) O(n)
# B) O(log n)
# C) O(n log n)
# D) O(1)
# Correct Answer: B) O(log n)
#
# **Question 20**
# What is the primary property of a Max-Heap? (Theoretical) (Max-Heap Characteristics)
# A) The value of each node is less than or equal to its children
# B) The value of each node is greater than or equal to its children
# C) The value of each node is equal to its children
# D) The value of each node is not related to its children
# Correct Answer: B) The value of each node is greater than or equal to its children
#
# **Question 21**
# What is the advantage of balanced trees in terms of time complexity? (Logical Reasoning) (Balanced Trees: AVL and Red-Black Trees)
# A) They are less efficient in terms of time complexity
# B) They are more efficient in terms of time complexity
# C) They are only used for small datasets
# D) They are not suitable for dynamic data
# Correct Answer: B) They are more efficient in terms of time complexity
#
# **Question 22**
# What is the primary application of linked lists? (Understanding) (Applications of Linked Lists)
# A) Memory management systems
# B) Undo functionality in applications
# C) Browser history navigation
# D) All of the above
# Correct Answer: D) All of the above
#
# **Question 23**
# What is the disadvantage of arrays in terms of insertion and deletion? (Remembering) (Disadvantages of Arrays)
# A) They are slower than linked lists
# B) They are faster than linked lists
# C) They are more memory-efficient than linked lists
# D) They are less complex than linked lists
# Correct Answer: A) They are slower than linked lists
#
# **Question 24**
# What is the advantage of arrays in terms of direct access? (Logical Reasoning) (Advantages of Arrays)
# A) They are slower than linked lists
# B) They are more complex than linked lists
# C) They allow for direct access to elements
# D) They are less memory-efficient than linked lists
# Correct Answer: C) They allow for direct access to elements
#
# **Question 25**
# What is the primary application of heaps? (Understanding) (Real-World Applications of Heaps)
# A) Priority queues
# B) Scheduling systems
# C) Database indexing
# D) All of the above
# Correct Answer: D) All of the above
#
# **Question 26**
# What is the time complexity of deletion in a Binary Search Tree? (Pseudocode) (Time Complexity of Binary Search Trees)
# A) O(n)
# B) O(log n)
# C) O(n log n)
# D) O(1)
# Correct Answer: B) O(log n)
#
# **Question 27**
# What is the primary advantage of arrays in terms of simplicity? (Logical Reasoning) (Advantages of Arrays)
# A) They are more complex than linked lists
# B) They are less memory-efficient than linked lists
# C) They have a straightforward structure
# D) They are slower than linked lists
# Correct Answer: C) They have a straightforward structure
#
# **Question 28**
# What is the disadvantage of linked lists in terms of memory usage? (Remembering) (Disadvantages of Linked Lists)
# A) They use less memory than arrays
# B) They use more memory than arrays
# C) They are only used for small datasets
# D) They are not suitable for dynamic data
# Correct Answer: B) They use more memory than arrays
#
# **Question 29**
# What is the primary application of Binary Search Trees in real-world scenarios? (Understanding) (Applications of Binary Search Trees)
# A) File system navigation
# B) Browser history navigation
# C) Database indexing
# D) All of the above
# Correct Answer: C) Database indexing
#
# **Question 30**
# What is the advantage of balanced trees in terms of height? (Theoretical) (Balanced Trees: AVL and Red-Black Trees)
# A) They have a larger height than unbalanced trees
# B) They have a smaller height than unbalanced trees
# C) They are more complex than unbalanced trees
# D) They are less efficient than unbalanced trees
# Correct Answer: B) They have a smaller height than unbalanced trees
# Quiz saved to Module1_Notes_to_Quiz/quiz.csv with 30 questions.
